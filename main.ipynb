# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.stats.stattools import jarque_bera
from statsmodels.stats.diagnostic import acorr_ljungbox
import openpyxl

data_df = pd.read_excel('USYIELDSLW - 8824.xlsx')

sample_length = np.size(data_df['Month'])
print("sample length =", sample_length)

print(data_df.head())
# Out:
# sample length = 444
#      Month        Y3        Y6        Y9       Y12       Y15       Y18  \
# 0  1988M01  5.962627  6.290226  6.540538  6.726668  6.875558  6.986386
# 1  1988M02  5.818902  6.144671  6.397897  6.586401  6.731627  6.848399
# 2  1988M03  6.068347  6.322001  6.590007  6.802500  6.963760  7.093201
# 3  1988M04  6.165915  6.549591  6.846607  7.072560  7.251806  7.395552
# 4  1988M05  6.643349  7.062711  7.365549  7.587756  7.762099  7.899609
#
#         Y21       Y24       Y30       Y36       Y48       Y60       Y72  \
# 0  7.065036  7.133453  7.266280  7.369855  7.563347  7.697265  7.909794
# 1  6.940780  7.013497  7.147030  7.257617  7.440661  7.590009  7.774056
# 2  7.202172  7.292476  7.448631  7.583159  7.837619  7.994832  8.198461
# 3  7.503140  7.592582  7.749566  7.877453  8.113482  8.249846  8.446218
# 4  7.998880  8.079097  8.201664  8.299064  8.511964  8.634990  8.786746
#
#         Y84       Y96      Y108      Y120
# 0  8.085070  8.177020  8.233017  8.294311
# 1  7.964320  8.077754  8.155330  8.233607
# 2  8.388738  8.489676  8.565883  8.639438
# 3  8.634031  8.729520  8.821633  8.901933
# 4  8.955737  9.061029  9.137936  9.202668
